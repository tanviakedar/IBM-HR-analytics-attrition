# %%
import pandas as pd

# %%
import numpy as np

# %%
 import matplotlib.pyplot as plt
 import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
 pd.set_option('display.max_columns',35)

# %%
 df=pd.read_csv(r'C:\Users\Admin\Desktop\projects\WA_Fn-UseC_-HR-Employee-Attrition.csv') #file path
 df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  Life Sciences               1
# 1                 8          1  Life Sciences               2
# 2                 2          2          Other               4
# 3                 3          4  Life Sciences               5
# 4                 2          1        Medical               7
#
#    EnvironmentSatisfaction  ... TrainingTimesLastYear  WorkLifeBalance  \
# 0                        2  ...                     0                1
# ...

# %%
df.shape            # Rows and columns
df.columns          # Column names
df.info()           # Data types, non-null counts
df.describe()       # Statistical summary of numeric columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeNumber            1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   object
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
# ...

# %%
df.isnull().sum()   # Check for nulls
df.dropna()         # Drop rows with missing values (if needed)
df.fillna(0)    # Fill missing values
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeNumber  \
# ...

# %%
#Duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
df['Attrition'].value_counts(normalize=True)
# Out:
# Attrition
# No     0.838776
# Yes    0.161224
# Name: proportion, dtype: float64

# %%
total_employees = df.shape[0]
print(f"Total Employees: {total_employees}")
# Out:
# Total Employees: 1470

# %%
attrition_counts = df['Attrition'].value_counts()
attrition_rate = (attrition_counts['Yes'] / total_employees) * 100
print(f"Attrition Rate: {attrition_rate:.2f}%")
# Out:
# Attrition Rate: 16.12%

# %%
sns.countplot(x='Attrition', data=df, palette={'Yes': 'blue', 'No': 'yellow'})
plt.title('Attrition Count')
plt.show()
print(attrition_counts)
print(df['Attrition'].value_counts(normalize=True) * 100)
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64
# Attrition
# No     83.877551
# Yes    16.122449
# Name: proportion, dtype: float64

# %%
# Attrition 'Yes' (blue bar): Around 250 employees left.
# Attrition 'No' (yellow bar): Over 1200 employees stayed.

# %%
sns.countplot(x='Gender', hue='Attrition', data=df, palette='Set1')
plt.title('Gender vs Attrition')
plt.show()

# %%
# Female Employees:
# Attrition 'Yes' (Red): ~90 employees left.
# Attrition 'No' (Blue): ~500 stayed.
# Attrition rate: ~15%

# Male Employees:
# Attrition 'Yes' (Red): ~150 employees left.
# Attrition 'No' (Blue): ~730 stayed.
# Attrition rate: ~17%

# %%
sns.barplot(x='Attrition', y='Age', data=df, palette='Set2')
plt.title('Age vs Attrition')
plt.show()

# %%
# Employees who left (‘Yes’): Average age is around 33–34 years.
# Employees who stayed (‘No’): Average age is closer to 38 years.
#Younger employees are more likely to leave the company.

# %%
sns.countplot(x='MaritalStatus', hue='Attrition', data=df, palette='coolwarm')
plt.title('Marital Status vs Attrition')
plt.show()
# Percentage of attrition by marital status
print(df.groupby('MaritalStatus')['Attrition'].value_counts(normalize=True).unstack() * 100)
# Out:
# Attrition             No        Yes
# MaritalStatus
# Divorced       89.908257  10.091743
# Married        87.518574  12.481426
# Single         74.468085  25.531915

# %%
# Singles have the highest attrition rate (the "Yes" bar is comparatively taller).
# Married employees make up the largest group, but their attrition rate is lower relative to their count.
# Divorced employees have the lowest attrition count.

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='JobRole', hue='Attrition', data=df, palette='Set3')
plt.title('Attrition by Job Role')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#1. Highest Attrition in Sales Executive & Laboratory Technician Roles
#Both roles show high counts of employees who left compared to others.
#Sales Executive and Laboratory Technician roles also have large total headcounts overall.

# 2.Research Scientist Also Shows Noticeable Attrition
#This role has a significant number of employees leaving, though not as much as the two roles above.

#3.Lowest Attrition in Manager and Healthcare Representative Roles
#Very few instances of attrition in these categories, suggesting better retention.

#4.Sales Representative Has a Relatively High Proportion of Attrition
# Despite having fewer total employees, the attrition proportion is high compared to others.

#5.Manufacturing Director, Research Director, and Human Resources Have Low Attrition
#These roles exhibit strong retention rates, with very few employees leaving.

# %%
sns.countplot(x='Department', hue='Attrition', data=df, palette='Paired')
plt.title('Attrition by Department')
plt.show()

# %%
# Research & Development (R&D) has the highest overall employee count: Attrition (leaving employees) is relatively lower compared to the total number staying.
# Sales Department shows a noticeable attrition rate:The gap between employees staying and leaving is smaller compared to R&D.
#                                                    Attrition is comparatively higher in Sales relative to its size.
# Human Resources has the lowest headcount overall:Attrition in HR is minimal, but given the small department size, even a few resignations could be impactful proportionally.

# %%
sns.countplot(x='OverTime', hue='Attrition', data=df, palette={'Yes': 'tomato', 'No': 'mediumseagreen'})
plt.title('Attrition by Overtime')
plt.show()

# %%
# Employees who work overtime have a higher attrition rate compared to those who don't.
# The number of employees leaving is significantly higher among those who are required to work overtime.
# Employees not working overtime show much lower attrition relative to their overall group size.
# Majority of employees without overtime responsibilities stay with the organization.

# %%
sns.kdeplot(data=df[df['Attrition']=='Yes']['YearsAtCompany'], label='Left', shade=True)
sns.kdeplot(data=df[df['Attrition']=='No']['YearsAtCompany'], label='Stayed', shade=True)
plt.title('Years at Company Distribution')
plt.legend()
plt.show()

# %%
# Employees who left the company (blue line) tend to have shorter tenures, mostly between 0 to 5 years.
# Employees who stayed (orange line) show a broader spread, with density peaking a bit later compared to those who left.
# After around 5–10 years, the attrition rate sharply drops, and most employees who stay tend to remain much longer.
# Very few employees leave after crossing around 10+ years at the company.

# %%
sns.barplot(x='Attrition', y='MonthlyIncome', data=df, palette={'Yes': 'olive', 'No': 'magenta'},ci=None)
plt.title('Monthly Income vs Attrition')
plt.show()

# %%
# Employees who left ("Yes") have a lower average monthly income (~4800).
# Employees who stayed ("No") have a higher average monthly income (~6800).
# The income gap is significant — almost 2000 units difference.

# %%
satisfaction_columns = ['JobSatisfaction', 'WorkLifeBalance', 'EnvironmentSatisfaction', 'RelationshipSatisfaction']

# Group by Attrition and calculate the mean for satisfaction scores
mean_satisfaction = df.groupby('Attrition')[satisfaction_columns].mean()
print(mean_satisfaction)
# Out:
#            JobSatisfaction  WorkLifeBalance  EnvironmentSatisfaction  \
# Attrition
# No                2.778589         2.781022                 2.771290
# Yes               2.468354         2.658228                 2.464135
#
#            RelationshipSatisfaction
# Attrition
# No                         2.733982
# Yes                        2.599156

# %%
# Job and environment satisfaction show the largest drops (about -0.31) for those who left.
# Even relationship satisfaction and work-life balance are slightly lower among employees who left.
# This confirms that lower satisfaction across the board correlates with attrition.

# %%
#Average of Tenure
#Average tenure: The average tenure measures the average number of years anemployee stays with the company before leaving. It can provide insight into workforcestability and employee satisfaction within the organization.
avg_tenure = df['YearsAtCompany'].mean()
print(f'Average years of employee to leave the company is{avg_tenure} years')
# Out:
# Average years of employee to leave the company is7.0081632653061225 years

# %%
sns.histplot(data=df, x='Age', bins=20, kde=True,color='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
 # Age: Most of the company's employees are in the 30-35 age group. Thisindicates that the company has many employees who are at a productive and experienced age.

# %%
sns.histplot(data=df, x='Age', hue='Gender', bins=20, kde=True, multiple='stack')
plt.title('Age Distribution by Gender')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
# Both female and male employees are most commonly in the 30–40 age range.
# The female distribution is more sharply peaked (centered near early 30s), suggesting a younger skew.
# The male distribution is more spread out, with a gentler decline into older ages.
# There are more females in the 25–40 age bracket, while males are more present in the 40–60 range

# %%
 sns.countplot(data=df, x='Gender',palette={'Male':'green','Female':'blue'})
 plt.title('Distribution Employee by Gender')
 plt.xlabel('Gender')
 plt.ylabel('Count')
plt.show()

# %%
# Males (~870) significantly outnumber females (~590) in this dataset.

# %%
 sns.countplot(data=df, x='Department',palette={'Research & Development':'red', 'Sales':'green', 'Human Resources':'blue'})
 plt.title('Distribution Employee by Department')
 plt.xlabel('Department')
 plt.ylabel('Count')
plt.show()

# %%
# Research & Development has the largest number of employees — around 950.
# Sales comes next with roughly 450 employees.
# Human Resources is the smallest department, with fewer than 100 employees.

# %%
# Breakdown of DistanceFromHome by JobRole and Attrition
plt.figure(figsize=(14, 6))
sns.barplot(data=df, x="JobRole", y="DistanceFromHome", hue="Attrition", estimator="mean", ci=None)
plt.title("Average Distance From Home by Job Role and Attrition")
plt.xticks(rotation=45)
plt.show()

# %%
# Certain roles like Sales Representatives and Laboratory Technicians show higher average distances among employees who left (Attrition = Yes).
# Roles like Healthcare Representative have relatively low distances regardless of attrition status.

# %%
#Compare Average Monthly Income by Education and Attrition
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x="Education", y="MonthlyIncome", hue="Attrition", estimator="mean", ci=None,palette={'Yes':'green','No':'yellow'})
plt.title("Average Monthly Income by Education Level and Attrition")
plt.tight_layout()
plt.show()

# %%
# Across all education levels, employees who stayed tend to earn more on average.
# The income gap between those who stayed and those who left is especially noticeable at higher education levels (Education 3 to 5).

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Attrition', y='TotalWorkingHours', data=df)
plt.title('Attrition by Total Working hours')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Attrition', y='TotalWorkingYears', data=df, hue='Attrition',palette={'Yes':'magenta','No':'green'}, dodge=False)
plt.title('Attrition by Total Working Years')
plt.legend([],[], frameon=False)  
plt.show()

# %%
# Attrition = Yes (Left):Median total working years is lower.
# Attrition = No (Stayed): Median total working years is higher.
# Interpretation: Employees who leave the company typically have less experience compared to those who stay longer.
# Attrition = Yes:Narrower IQR (middle 50% of data is closer together).
# Attrition = No:Wider IQR (more variation in total working years among those who stay).
# Interpretation:Employees who leave tend to have a more similar (low) amount of total working years, while those who stay have more diverse career lengths.
# Employees with fewer total working years are more likely to leave.
# Employees who stay tend to have longer careers.
# Attrition is higher among less experienced employees.
# There are a few outliers where even highly experienced employees leave, but it’s rare.

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Attrition', y='MonthlyRate', data=df)
plt.title('Attrition by Monthly rate')
plt.show()

# %%
# The monthly salary distribution is very similar between employees who left ("Yes") and those who stayed ("No").
# Medians are almost the same for both groups.
# Spread (range and IQR) is also quite similar, suggesting that salary level (monthly rate) does not strongly impact attrition.
# No significant outliers or pattern differences observed between the two groups.

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Attrition', y='HourlyRate', data=df,hue='Attrition',palette={'Yes':'pink','No':'yellow'}, dodge=False)
plt.title('Attrition by Hourly rate')
plt.show()

# %%
# Hourly rates are very similar between employees who left ("Yes") and those who stayed ("No").
# Medians and spreads (IQR and range) are almost identical for both groups.
# No major difference in hourly pay appears to be related to attrition.
# Both groups cover a wide range of hourly rates (from ~30 to 100).

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Attrition', y='PercentSalaryHike', data=df,hue='Attrition',palette={'Yes':'blue','No':'green'}, dodge=False)
plt.title('Attrition by PercentSalaryHike')
plt.show()

# %%
# The average percent salary hike is almost the same for employees who left and those who stayed.
# Very small difference, suggesting salary hikes did not significantly influence attrition.
